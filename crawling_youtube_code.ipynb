# %% [markdown]
# # Youtube API를 통한 크롤링

# %% [markdown]
# # 나경원 류삼영 키워드

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

import pandas as pd
import numpy as np
from datetime import datetime
import time
import re

import logging



# 로그 설정
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# 콘솔 핸들러 추가
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)

# 파일 핸들러 추가
file_handler = logging.FileHandler('youtube_scraping.log', mode='a')
file_handler.setLevel(logging.INFO)

# 로그 포맷 설정
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
console_handler.setFormatter(formatter)
file_handler.setFormatter(formatter)

# 핸들러를 로거에 추가
logger.addHandler(console_handler)
logger.addHandler(file_handler)

# 여러 YouTube API 키 설정
api_keys = [
    'AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ',
    'AIzaSyDJM3LwPtAyzg4Ir479E3E561W5lFm72xs',
    'AIzaSyB3INmnCFrJHIbO54cMZFTPe7vau1vgbtY'
]

current_key_index = 0

def get_youtube_client():
    global current_key_index
    api_key = api_keys[current_key_index]
    youtube = build('youtube', 'v3', developerKey=api_key)
    return youtube

youtube = get_youtube_client()

def switch_api_key():
    global current_key_index, youtube
    current_key_index = (current_key_index + 1) % len(api_keys)
    logger.info(f"Switching to API key: {current_key_index + 1}")
    youtube = get_youtube_client()
    return youtube

# 검색어 및 설정
search_query = "나경원 류삼영"
start_date = datetime.strptime("2024-03-01", "%Y-%m-%d")
end_date = datetime.strptime("2024-04-30", "%Y-%m-%d")



# 불법 문자 제거 함수
def remove_illegal_characters(text):
    illegal_chars = re.compile(r'[\000-\010]|[\013-\014]|[\016-\037]')
    return illegal_chars.sub('', text)



def search_videos(query, start_date, end_date):
    video_details = []
    request = youtube.search().list(
        q=query,
        part='id,snippet',
        type='video',
        order='date',
        maxResults=100  # 한 번에 최대 100개 가져오기
    )

    while request:
        try:
            response = request.execute()
        except HttpError as e:
            if e.resp.status in [403, 500, 503]:
                logger.error(f"Quota exceeded or server error: {e}. Switching API key.")
                switch_api_key()
                continue
            else:
                logger.error(f"HttpError occurred: {e}")
                break
        except Exception as e:
            logger.error(f"Error during video search: {e}")
            break

        for item in response['items']:
            video_id = item['id']['videoId']
            title = item['snippet']['title']
            published_at = item['snippet']['publishedAt']
            published_at_date = datetime.strptime(published_at, "%Y-%m-%dT%H:%M:%SZ")

            # 날짜 조건 확인
            if published_at_date < start_date:
                return video_details
            if published_at_date > end_date:
                continue

            video_url = f'https://www.youtube.com/watch?v={video_id}'
            video_details.append({
                'video_id': video_id,
                'title': title,
                'published_at': published_at,
                'url': video_url
            })

        logger.info(f"Found {len(video_details)} videos so far...")
        request = youtube.search().list_next(request, response)
        time.sleep(1)  # 요청 간 지연 추가

    return video_details

def get_video_statistics(video_id):
    try:
        request = youtube.videos().list(
            part='statistics',
            id=video_id
        )
        response = request.execute()
        if response['items']:
            stats = response['items'][0]['statistics']
            view_count = stats.get('viewCount', 0)
            like_count = stats.get('likeCount', 0)
            return view_count, like_count
    except HttpError as e:
        if e.resp.status in [403, 500, 503]:
            logger.error(f"Quota exceeded or server error: {e}. Switching API key.")
            switch_api_key()
            return get_video_statistics(video_id)
        else:
            logger.error(f"HttpError occurred while retrieving statistics: {e}")
            return 0, 0
    except Exception as e:
        logger.error(f"Error retrieving statistics for video {video_id}: {e}")
    return 0, 0

def get_video_comments(video_id):
    comments = []

    request = youtube.commentThreads().list(
        part='snippet',
        videoId=video_id,
        maxResults=100,  # 한 번에 최대 100개 가져오기
        textFormat='plainText'
    )

    while request:
        try:
            response = request.execute()
        except HttpError as e:
            if e.resp.status in [403, 500, 503]:
                logger.error(f"Quota exceeded or server error: {e}. Switching API key.")
                switch_api_key()
                continue
            else:
                logger.error(f"HttpError occurred: {e}")
                break
        except Exception as e:
            logger.error(f"Error retrieving comments for video {video_id}: {e}")
            break

        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            comment_data = {
                'comment_id': item['id'],
                'video_id': video_id,
                'parent_id': None,
                'author': comment['authorDisplayName'],
                'text': comment['textDisplay'],
                'like_count': comment['likeCount'],
                'published_at': comment['publishedAt']
            }
            comments.append(comment_data)

            total_reply_count = item['snippet']['totalReplyCount']
            if total_reply_count > 0:
                replies = get_replies(item['id'], video_id)
                comments.extend(replies)

        request = youtube.commentThreads().list_next(request, response)
        time.sleep(1)  # 요청 간 지연 추가

    return comments

def get_replies(parent_id, video_id):
    replies = []
    request = youtube.comments().list(
        part='snippet',
        parentId=parent_id,
        maxResults=100,  # 한 번에 최대 100개 가져오기
        textFormat='plainText'
    )
    while request:
        try:
            response = request.execute()
        except HttpError as e:
            if e.resp.status in [403, 500, 503]:
                logger.error(f"Quota exceeded or server error: {e}. Switching API key.")
                switch_api_key()
                continue
            else:
                logger.error(f"HttpError occurred: {e}")
                break
        except Exception as e:
            logger.error(f"Error retrieving replies for comment {parent_id}: {e}")
            break

        for item in response['items']:
            reply = item['snippet']
            reply_data = {
                'comment_id': item['id'],
                'video_id': video_id,
                'parent_id': parent_id,
                'author': reply['authorDisplayName'],
                'text': reply['textDisplay'],
                'like_count': reply['likeCount'],
                'published_at': reply['publishedAt']
            }
            replies.append(reply_data)

        request = youtube.comments().list_next(request, response)
        time.sleep(1)  # 요청 간 지연 추가

    return replies

# 동영상 검색
start_time = time.time()
video_details = search_videos(search_query, start_date, end_date)
logger.info(f"Total videos found: {len(video_details)}")

# 모든 동영상의 통계 및 댓글 가져오기
all_data = []
total_videos = len(video_details)
for i, video in enumerate(video_details):
    video_start_time = time.time()
    video_id = video['video_id']
    try:
        view_count, like_count = get_video_statistics(video_id)
        comments = get_video_comments(video_id)
        for comment in comments:
            all_data.append({
                'video_id': video_id,
                'title': video['title'],
                'published_at': video['published_at'],
                'view_count': view_count,
                'like_count': like_count,
                'url': video['url'],
                'comment_id': comment['comment_id'],
                'parent_id': comment['parent_id'],
                'author': comment['author'],
                'text': comment['text'],
                'comment_like_count': comment['like_count'],
                'comment_published_at': comment['published_at']
            })
    except Exception as e:
        logger.error(f"Error processing video {video_id}: {e}")
        break

    video_end_time = time.time()
    elapsed_time = video_end_time - video_start_time
    total_elapsed_time = video_end_time - start_time

    # 진행 상황 출력
    logger.info(f"Processed video {i + 1}/{total_videos} ({(i + 1) / total_videos * 100:.2f}%) - {video_id}, comments retrieved: {len(comments)}, time elapsed for this video: {elapsed_time:.2f}s, total elapsed time: {total_elapsed_time:.2f}s")

# 데이터프레임으로 변환
df = pd.DataFrame(all_data)

# 데이터 저장 함수
def save_large_dataframe(df, base_filename, max_rows_per_file=100000):
    try:
        df.to_csv(f'{base_filename}.csv', index=False)
        df.to_excel(f'{base_filename}.xlsx', index=False)
        logger.info(f"Data successfully saved to {base_filename}.csv and {base_filename}.xlsx")
    except Exception as e:
        logger.error(f"Error saving full dataframe: {e}")
        num_parts = int(np.ceil(len(df) / max_rows_per_file))
        logger.info(f"Splitting data into {num_parts} parts due to size limit.")

        for part in range(num_parts):
            start_row = part * max_rows_per_file
            end_row = min((part + 1) * max_rows_per_file, len(df))
            df_part = df.iloc[start_row:end_row]
            part_filename = f'{base_filename}_part{part + 1}'
            try:
                df_part.to_csv(f'{part_filename}.csv', index=False)
                df_part.to_excel(f'{part_filename}.xlsx', index=False)
                logger.info(f"Data part {part + 1} saved to {part_filename}.csv and {part_filename}.xlsx")
            except Exception as e_part:
                logger.error(f"Error saving part {part + 1} of dataframe: {e_part}")

# 데이터 저장 시도
save_large_dataframe(df, 'youtube_videos_with_comments_240301_240430')

logger.info("데이터 저장이 완료되었습니다.")
# Out:
# 2024-06-04 08:19:58,588 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 08:19:59,276 - INFO - Found 49 videos so far...
# 2024-06-04 08:20:00,769 - INFO - Found 99 videos so far...
# 2024-06-04 08:20:02,109 - INFO - Found 149 videos so far...
# 2024-06-04 08:20:03,593 - INFO - Found 199 videos so far...
# 2024-06-04 08:20:05,082 - INFO - Found 249 videos so far...
# 2024-06-04 08:20:06,590 - INFO - Found 299 videos so far...
# 2024-06-04 08:20:07,846 - INFO - Total videos found: 300
# 2024-06-04 08:20:14,709 - INFO - Processed video 1/300 (0.33%) - XZGyguAz9k0, comments retrieved: 76, time elapsed for this video: 3.72s, total elapsed time: 16.06s
# 2024-06-04 08:20:17,112 - INFO - Processed video 2/300 (0.67%) - xWd6Ixzd3sw, comments retrieved: 11, time elapsed for this video: 2.40s, total elapsed time: 18.46s
# 2024-06-04 08:20:23,050 - INFO - Processed video 3/300 (1.00%) - 4MnWXHlzuBY, comments retrieved: 33, time elapsed for this video: 5.94s, total elapsed time: 24.40s
# 2024-06-04 08:20:24,298 - INFO - Processed video 4/300 (1.33%) - fDqELUWYgM0, comments retrieved: 4, time elapsed for this video: 1.25s, total elapsed time: 25.65s
# 2024-06-04 08:20:26,712 - INFO - Processed video 5/300 (1.67%) - O-exv1xPik8, comments retrieved: 10, time elapsed for this video: 2.41s, total elapsed time: 28.06s
# 2024-06-04 08:20:32,620 - INFO - Processed video 6/300 (2.00%) - MzWdg6PE0Zc, comments retrieved: 45, time elapsed for this video: 5.90s, total elapsed time: 33.97s
# 2024-06-04 08:58:09,590 - INFO - Processed video 108/300 (36.00%) - YhG23b-7mgs, comments retrieved: 231, time elapsed for this video: 16.65s, total elapsed time: 2290.94s
# 2024-06-04 09:10:33,508 - INFO - Processed video 109/300 (36.33%) - 4vLni68uw88, comments retrieved: 14934, time elapsed for this video: 743.90s, total elapsed time: 3034.86s
# 2024-06-04 09:11:04,402 - INFO - Processed video 110/300 (36.67%) - iKoLp6jg8YE, comments retrieved: 372, time elapsed for this video: 30.89s, total elapsed time: 3065.75s
# 2024-06-04 09:11:37,478 - INFO - Processed video 111/300 (37.00%) - _p3ZdI8GxYk, comments retrieved: 364, time elapsed for this video: 33.07s, total elapsed time: 3098.83s
# 2024-06-04 09:13:02,751 - INFO - Processed video 112/300 (37.33%) - xTiGw-w1D0s, comments retrieved: 1083, time elapsed for this video: 85.27s, total elapsed time: 3184.10s
# 2024-06-04 09:14:04,361 - INFO - Processed video 113/300 (37.67%) - 7bK5hLQF5Ps, comments retrieved: 679, time elapsed for this video: 61.61s, total elapsed time: 3245.71s
# 2024-06-04 09:14:06,827 - INFO - Processed video 114/300 (38.00%) - d2sD6dWDfxk, comments retrieved: 5, time elapsed for this video: 2.46s, total elapsed time: 3248.18s
# 2024-06-04 09:14:08,144 - INFO - Processed video 115/300 (38.33%) - wLeDaKM5nPU, comments retrieved: 5, time elapsed for this video: 1.32s, total elapsed time: 3249.49s
# 2024-06-04 09:14:10,657 - INFO - Processed video 116/300 (38.67%) - JgFMNMkHzwQ, comments retrieved: 42, time elapsed for this video: 2.51s, total elapsed time: 3252.01s
# 2024-06-04 09:14:10,840 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:10,842 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:10,842 - INFO - Switching to API key: 2
# 2024-06-04 09:14:10,847 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:10,935 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:10,936 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:10,936 - INFO - Switching to API key: 3
# 2024-06-04 09:14:10,938 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,020 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,020 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,021 - INFO - Switching to API key: 1
# 2024-06-04 09:14:11,022 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,106 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,107 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,107 - INFO - Switching to API key: 2
# 2024-06-04 09:14:11,109 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,209 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,221 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,227 - INFO - Switching to API key: 3
# 2024-06-04 09:14:11,233 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,319 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,320 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,320 - INFO - Switching to API key: 1
# 2024-06-04 09:14:11,322 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,406 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,407 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,407 - INFO - Switching to API key: 2
# 2024-06-04 09:14:11,408 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,497 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,497 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,498 - INFO - Switching to API key: 3
# 2024-06-04 09:14:11,499 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,580 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,581 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,581 - INFO - Switching to API key: 1
# 2024-06-04 09:14:11,582 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,664 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,665 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,666 - INFO - Switching to API key: 2
# 2024-06-04 09:14:11,668 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,757 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,758 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,758 - INFO - Switching to API key: 3
# 2024-06-04 09:14:11,760 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,843 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,845 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,846 - INFO - Switching to API key: 1
# 2024-06-04 09:14:11,847 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:11,934 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:11,935 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:11,935 - INFO - Switching to API key: 2
# 2024-06-04 09:14:11,937 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:12,023 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:12,023 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:12,024 - INFO - Switching to API key: 3
# 2024-06-04 09:14:12,025 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:12,116 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:12,117 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:12,117 - INFO - Switching to API key: 1
# 2024-06-04 09:14:12,121 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:12,204 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:12,204 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:12,205 - INFO - Switching to API key: 2
# 2024-06-04 09:14:12,206 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:12,293 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:12,293 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:12,294 - INFO - Switching to API key: 3
# 2024-06-04 09:14:12,295 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:12,383 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:12,384 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:12,384 - INFO - Switching to API key: 1
# 2024-06-04 09:14:12,386 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:12,474 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:12,475 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:12,475 - INFO - Switching to API key: 2
# 2024-06-04 09:14:12,477 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:12,565 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:12,566 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:12,566 - INFO - Switching to API key: 3
# 2024-06-04 09:14:12,568 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:12,843 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:12,843 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:12,844 - INFO - Switching to API key: 1
# 2024-06-04 09:14:12,845 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:12,926 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:12,927 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:12,927 - INFO - Switching to API key: 2
# 2024-06-04 09:14:12,929 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:13,009 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:13,010 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:13,011 - INFO - Switching to API key: 3
# 2024-06-04 09:14:13,012 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:13,097 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:13,098 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:13,098 - INFO - Switching to API key: 1
# 2024-06-04 09:14:13,100 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:13,183 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:13,184 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:13,184 - INFO - Switching to API key: 2
# 2024-06-04 09:14:13,186 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:13,270 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:13,271 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:13,271 - INFO - Switching to API key: 3
# 2024-06-04 09:14:13,275 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:13,359 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:13,360 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:13,361 - INFO - Switching to API key: 1
# 2024-06-04 09:14:13,362 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:13,446 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:14:13,447 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:14:13,447 - INFO - Switching to API key: 2
# 2024-06-04 09:14:13,449 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:14:13,527 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# ...
# 2024-06-04 09:15:22,283 - INFO - Switching to API key: 2
# 2024-06-04 09:15:22,284 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:22,376 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:22,378 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:22,381 - INFO - Switching to API key: 3
# 2024-06-04 09:15:22,383 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:22,473 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:22,474 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:22,475 - INFO - Switching to API key: 1
# 2024-06-04 09:15:22,479 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:22,562 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:22,564 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:22,566 - INFO - Switching to API key: 2
# 2024-06-04 09:15:22,569 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:22,652 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:22,653 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:22,655 - INFO - Switching to API key: 3
# 2024-06-04 09:15:22,658 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:22,745 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:22,747 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:22,748 - INFO - Switching to API key: 1
# 2024-06-04 09:15:22,750 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:22,868 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:22,869 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:22,869 - INFO - Switching to API key: 2
# 2024-06-04 09:15:22,870 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:22,963 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:22,964 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:22,964 - INFO - Switching to API key: 3
# 2024-06-04 09:15:22,966 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:23,054 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:23,056 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:23,057 - INFO - Switching to API key: 1
# 2024-06-04 09:15:23,061 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:23,148 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:23,149 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:23,149 - INFO - Switching to API key: 2
# 2024-06-04 09:15:23,151 - INFO - file_cache is only supported with oauth2client<4.0.0
# 2024-06-04 09:15:23,247 - WARNING - Encountered 403 Forbidden with reason "commentsDisabled"
# 2024-06-04 09:15:23,248 - ERROR - Quota exceeded or server error: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=1YpSZnIPdjc&maxResults=100&textFormat=plainText&key=AIzaSyBBy5R-f80i3xfXoj3NC3Qi6d9cqmjRUWQ&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">. Switching API key.
# 2024-06-04 09:15:23,250 - INFO - Switching to API key: 3
# 2024-06-04 09:15:23,253 - INFO - file_cache is only supported with oauth2client<4.0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 242
#     240 try:
#     241     view_count, like_count = get_video_statistics(video_id)
# --> 242     comments = get_video_comments(video_id)
#     243     for comment in comments:
#     244         all_data.append({
#     245             'video_id': video_id,
#     246             'title': video['title'],
#    (...)
#     256             'comment_published_at': comment['published_at']
#     257         })
#
# Cell In[9], line 152, in get_video_comments(video_id)
#     150 while request:
#     151     try:
# --> 152         response = request.execute()
#     153     except HttpError as e:
#     154         if e.resp.status in [403, 500, 503]:
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/site-packages/googleapiclient/http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/site-packages/googleapiclient/http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/site-packages/httplib2/__init__.py:1724, in Http.request(self, uri, method, body, headers, redirections, connection_type)
#    1722             content = b""
#    1723         else:
# -> 1724             (response, content) = self._request(
#    1725                 conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1726             )
#    1727 except Exception as e:
#    1728     is_timeout = isinstance(e, socket.timeout)
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/site-packages/httplib2/__init__.py:1444, in Http._request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1441 if auth:
#    1442     auth.request(method, request_uri, headers, body)
# -> 1444 (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1446 if auth:
#    1447     if auth.response(response, body):
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/site-packages/httplib2/__init__.py:1396, in Http._conn_request(self, conn, request_uri, method, body, headers)
#    1394     pass
#    1395 try:
# -> 1396     response = conn.getresponse()
#    1397 except (http.client.BadStatusLine, http.client.ResponseNotReady):
#    1398     # If we get a BadStatusLine on the first try then that means
#    1399     # the connection just went stale, so retry regardless of the
#    1400     # number of RETRIES set.
#    1401     if not seen_bad_status_line and i == 1:
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/envs/election_youtube/lib/python3.8/ssl.py:1132, in SSLSocket.read(self, len, buffer)
#    1130 try:
#    1131     if buffer is not None:
# -> 1132         return self._sslobj.read(len, buffer)
#    1133     else:
#    1134         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# 데이터프레임으로 변환
df = pd.DataFrame(all_data)

# CSV 파일로 저장
df.to_csv('youtube_videos_with_comments.csv', index=False)
df.to_excel('youtube_videos_with_comments.xlsx', index=False)

print("데이터가 youtube_videos_with_comments.csv 파일에 저장되었습니다.")
# Out:
# 데이터가 youtube_videos_with_comments.csv 파일에 저장되었습니다.

# %%
import os
import platform
import time

def play_sound(times=10):
    if platform.system() == 'Windows':
        import winsound
        for _ in range(times):
            winsound.Beep(1000, 500)  # 1kHz sound for 0.5 seconds
            time.sleep(0.1)  # 0.1 second pause between beeps
    elif platform.system() == 'Darwin':  # macOS
        for _ in range(times):
            os.system('afplay /System/Library/Sounds/Ping.aiff')
            time.sleep(0.5)  # 0.5 second pause between sounds
    else:  # Linux
        for _ in range(times):
            os.system('aplay /usr/share/sounds/alsa/Front_Center.wav')
            time.sleep(0.5)  # 0.5 second pause between sounds

play_sound(10)

# %% [markdown]
# ---
